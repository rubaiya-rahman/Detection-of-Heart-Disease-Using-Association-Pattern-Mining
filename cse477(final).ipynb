# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth
from mlxtend.frequent_patterns import association_rules
data = pd.read_csv('heart.csv',header = None)
minimum_support_count = 2
records = []
for i in range(0, 1025):
    records.append([str(data.values[i,j]) for j in range(0, 14)])
te = TransactionEncoder()
te_ary = te.fit(records).transform(records)
df = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = fpgrowth(df, min_support=0.2, use_colnames=True)
rules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
rules["antecedent_len"] =rules["antecedents"].apply(lambda x: len(x))
rules[ (rules['antecedent_len'] >= 3) &
       (rules['confidence'] > 0.9) &
       (rules['lift'] > 1.2) ]
# Out:
#                                             antecedents  \
# 51    (having ST-T wave abnormality, heart disease f...
# 76    (having ST-T wave abnormality, fixed defect, h...
# 81    (fasting blood sugar <= 120 mg/dl, having ST-T...
# 333       (no major vessels, downsloping, fixed defect)
# 337       (no major vessels, downsloping, fixed defect)
# 426    (fixed defect, downsloping, heart disease found)
# 443   (fasting blood sugar <= 120 mg/dl, downsloping...
# 453   (fixed defect, downsloping, heart disease foun...
# 580           (male, reversable defect, typical angina)
# 585   (fasting blood sugar <= 120 mg/dl, reversable ...
# 589           (high, reversable defect, typical angina)
# 680   (fasting blood sugar <= 120 mg/dl, exercise in...
# 1022  (no major vessels, fixed defect, no exercise i...
# 1113  (fixed defect, heart disease found, no ST segm...
# 1129  (fasting blood sugar <= 120 mg/dl, no ST segme...
# 1168  (no major vessels, fixed defect, no ST segment...
# ...

# %%
healthy=rules[(rules['consequents'] == {'healthy'})&
             (rules['antecedent_len'] >= 3) &
            (rules['confidence'] > 0.9) &
            (rules['lift'] > 1) ]
healthy
# Out:
#                                            antecedents consequents  \
# 580          (male, reversable defect, typical angina)   (healthy)
# 585  (fasting blood sugar <= 120 mg/dl, reversable ...   (healthy)
# 589          (high, reversable defect, typical angina)   (healthy)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 580            0.226341            0.485854  0.205854    0.909483  1.871927
# 585            0.221463            0.485854  0.203902    0.920705  1.895025
# 589            0.218537            0.485854  0.200976    0.919643  1.892839
#
#      leverage  conviction  antecedent_len
# 580  0.095885    5.680093               3
# 585  0.096304    6.483957               3
# 589  0.094799    6.398266               3

# %%
sick=rules[(rules['consequents'] == {'heart disease found'})&
             (rules['antecedent_len'] >= 3) &
            (rules['confidence'] > 0.9) &
            (rules['lift'] > 1) ]

sick
# Out:
#                                             antecedents  \
# 333       (no major vessels, downsloping, fixed defect)
# 1022  (no major vessels, fixed defect, no exercise i...
# 1168  (no major vessels, fixed defect, no ST segment...
# 1185  (fasting blood sugar <= 120 mg/dl, no major ve...
# 1195  (no major vessels, fixed defect, no exercise i...
#
#                 consequents  antecedent support  consequent support   support  \
# 333   (heart disease found)            0.219512            0.513171  0.204878
# 1022  (heart disease found)            0.305366            0.513171  0.277073
# 1168  (heart disease found)            0.247805            0.513171  0.227317
# 1185  (heart disease found)            0.232195            0.513171  0.211707
# 1195  (heart disease found)            0.218537            0.513171  0.203902
#
#       confidence      lift  leverage  conviction  antecedent_len
# 333     0.933333  1.818758  0.092231    7.302439               3
# ...

# %%
#FEMALE

d=pd.read_csv('heart.csv')
female=d[d.sex=='female']
#df=pd.read_csv('heart.csv',head=None)
frecords = []
for i in range(0, 312):
    frecords.append([str(female.values[i,j]) for j in range(0, 14)])
te = TransactionEncoder()
te_ary = te.fit(frecords).transform(frecords)
fdf = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = fpgrowth(fdf, min_support=0.1, use_colnames=True)
frules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
frules["antecedent_len"] =frules["antecedents"].apply(lambda x: len(x))
frules[ (frules['antecedent_len'] >= 3) &
       (frules['confidence'] > 0.99) &
       (frules['lift'] > 1) ]
# Out:
#                                              antecedents  \
# 475    (fasting blood sugar <= 120 mg/dl, high, havin...
# 498    (fasting blood sugar <= 120 mg/dl, high, havin...
# 504    (fasting blood sugar <= 120 mg/dl, high, havin...
# 647    (fasting blood sugar <= 120 mg/dl, having ST-T...
# 662    (fasting blood sugar <= 120 mg/dl, having ST-T...
# ...                                                  ...
# 56514  (no major vessels, having ST-T wave abnormalit...
# 56515  (fixed defect, having ST-T wave abnormality, e...
# 56517  (no major vessels, having ST-T wave abnormalit...
# 56518  (fixed defect, having ST-T wave abnormality, e...
# 56519   (having ST-T wave abnormality, elevated, female)
#
#                             consequents  antecedent support  \
# 475               (heart disease found)            0.272436
# 498               (heart disease found)            0.272436
# 504       (heart disease found, female)            0.272436
# ...

# %%
female['target'].value_counts()
# Out:
# heart disease found    226
# healthy                 86
# Name: target, dtype: int64

# %%
healthy=frules[(frules['consequents'] == {'healthy'})&
             (frules['antecedent_len'] >= 3) &
            (frules['confidence'] > 0.95) &
            (frules['lift'] > 1)]
healthy
# Out:
#                                              antecedents consequents  \
# 31115        (reversable defect, female, typical angina)   (healthy)
# 31142          (reversable defect, typical angina, flat)   (healthy)
# 31149  (reversable defect, female, typical angina, flat)   (healthy)
# 31199          (reversable defect, high, typical angina)   (healthy)
# 31211  (typical angina, reversable defect, high, female)   (healthy)
#
#        antecedent support  consequent support   support  confidence      lift  \
# 31115            0.137821            0.275641  0.137821         1.0  3.627907
# 31142            0.115385            0.275641  0.115385         1.0  3.627907
# 31149            0.115385            0.275641  0.115385         1.0  3.627907
# 31199            0.105769            0.275641  0.105769         1.0  3.627907
# 31211            0.105769            0.275641  0.105769         1.0  3.627907
#
#        leverage  conviction  antecedent_len
# ...

# %%
frequent_itemsets = fpgrowth(fdf, min_support=0.3, use_colnames=True)
frules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)

sick=frules[(frules['consequents'] == {'heart disease found'})&
            (frules['confidence'] > 0.98) &
            (frules['lift'] > 1) ]

sick
# Out:
#                                             antecedents  \
# 396   (fasting blood sugar <= 120 mg/dl, having ST-T...
# 411   (fasting blood sugar <= 120 mg/dl, having ST-T...
# 3620                   (non-anginal pain, fixed defect)
# 3627           (non-anginal pain, fixed defect, female)
#
#                 consequents  antecedent support  consequent support   support  \
# 396   (heart disease found)            0.358974            0.724359  0.358974
# 411   (heart disease found)            0.358974            0.724359  0.358974
# 3620  (heart disease found)            0.307692            0.724359  0.307692
# 3627  (heart disease found)            0.307692            0.724359  0.307692
#
#       confidence      lift  leverage  conviction
# 396          1.0  1.380531  0.098948         inf
# 411          1.0  1.380531  0.098948         inf
# 3620         1.0  1.380531  0.084813         inf
# 3627         1.0  1.380531  0.084813         inf

# %%
##MALE

d=pd.read_csv('heart.csv')
male=d[d.sex=='male']
mrecords = []
for i in range(0, 713):
    mrecords.append([str(male.values[i,j]) for j in range(0, 14)])
te = TransactionEncoder()
te_ary = te.fit(mrecords).transform(mrecords)
mdf = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = fpgrowth(mdf, min_support=0.3, use_colnames=True)
mrules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
mrules["antecedent_len"] =mrules["antecedents"].apply(lambda x: len(x))
mrules[ (mrules['antecedent_len'] >= 3) &
       (mrules['confidence'] > 0.8) &
       (mrules['lift'] > 1.2) ]
# Out:
#                                            antecedents  \
# 92   (male, fasting blood sugar <= 120 mg/dl, typic...
# 112                       (male, high, typical angina)
# 126                     (male, normal, typical angina)
# 245    (male, downsloping, no exercise induced angina)
# 246      (male, downsloping, no ST segment depression)
# 265  (male, downsloping, fasting blood sugar <= 120...
# 274                          (male, downsloping, high)
#
#                       consequents  antecedent support  consequent support  \
# 92                      (healthy)            0.444600            0.579243
# 112                     (healthy)            0.413745            0.579243
# 126                     (healthy)            0.363254            0.579243
# 245    (no ST segment depression)            0.353436            0.511921
# 246  (no exercise induced angina)            0.367461            0.619916
# 265    (no ST segment depression)            0.394109            0.511921
# ...

# %%
male['target'].value_counts()
# Out:
# healthy                413
# heart disease found    300
# Name: target, dtype: int64

# %%
healthy=mrules[(mrules['consequents'] == {'healthy'})&
             (mrules['antecedent_len'] >= 3) &
            (mrules['confidence'] > 0.8) &
            (mrules['lift'] > 1) ]
healthy
# Out:
#                                            antecedents consequents  \
# 92   (male, fasting blood sugar <= 120 mg/dl, typic...   (healthy)
# 112                       (male, high, typical angina)   (healthy)
# 126                     (male, normal, typical angina)   (healthy)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 92             0.444600            0.579243  0.359046    0.807571  1.394184
# 112            0.413745            0.579243  0.336606    0.813559  1.404523
# 126            0.363254            0.579243  0.302945    0.833977  1.439771
#
#      leverage  conviction  antecedent_len
# 92   0.101515    2.186559               3
# 112  0.096947    2.256789               3
# 126  0.092533    2.534329               3

# %%
healthy=mrules[(mrules['consequents'] == {'heart disease found'})&
             (mrules['antecedent_len'] >= 3) &
            (mrules['confidence'] > 0.9) &
            (mrules['lift'] > 1) ]

sick
# Out:
#                                             antecedents  \
# 396   (fasting blood sugar <= 120 mg/dl, having ST-T...
# 411   (fasting blood sugar <= 120 mg/dl, having ST-T...
# 3620                   (non-anginal pain, fixed defect)
# 3627           (non-anginal pain, fixed defect, female)
#
#                 consequents  antecedent support  consequent support   support  \
# 396   (heart disease found)            0.358974            0.724359  0.358974
# 411   (heart disease found)            0.358974            0.724359  0.358974
# 3620  (heart disease found)            0.307692            0.724359  0.307692
# 3627  (heart disease found)            0.307692            0.724359  0.307692
#
#       confidence      lift  leverage  conviction
# 396          1.0  1.380531  0.098948         inf
# 411          1.0  1.380531  0.098948         inf
# 3620         1.0  1.380531  0.084813         inf
# 3627         1.0  1.380531  0.084813         inf

# %%
#CHESTPAIN
#TYPICALANGINA

da= pd.read_csv('heart.csv')
typical_angina= d[d.cp=='typical angina']
arecords = []
for i in range(0, 496):
    arecords.append([str(typical_angina.values[i,j]) for j in range(0, 14)])
te = TransactionEncoder()
te_ary = te.fit(arecords).transform(arecords)
fdf = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = fpgrowth(fdf, min_support=0.1, use_colnames=True)
arules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
arules["antecedent_len"] =arules["antecedents"].apply(lambda x: len(x))
arules[ (arules['antecedent_len'] >= 3) &
       (arules['confidence'] > 0.9) &
       (arules['lift'] > 1) ]
# Out:
#                                              antecedents  \
# 122            (male, reversable defect, typical angina)
# 140    (fasting blood sugar <= 120 mg/dl, reversable ...
# 154    (male, reversable defect, fasting blood sugar ...
# 162    (fasting blood sugar <= 120 mg/dl, reversable ...
# 166    (fasting blood sugar <= 120 mg/dl, reversable ...
# ...                                                  ...
# 20742                    (41-50, no major vessels, male)
# 20749    (male, no major vessels, 41-50, typical angina)
# 20752                    (male, no major vessels, 41-50)
# 20773                   (41-50, healthy, typical angina)
# 20776                   (41-50, healthy, typical angina)
#
#                                              consequents  antecedent support  \
# 122                                            (healthy)            0.467742
# 140                                            (healthy)            0.457661
# ...

# %%
typical_angina['target'].value_counts()
# Out:
# healthy                375
# heart disease found    122
# Name: target, dtype: int64

# %%
healthy=arules[(arules['consequents'] == {'healthy'})&
             (arules['antecedent_len'] >= 3) &
            (arules['confidence'] > 0.95) &
            (arules['lift'] > 1)]
healthy
# Out:
#                                              antecedents consequents  \
# 279    (reversable defect, exercise induced angina, t...   (healthy)
# 496    (normal, exercise induced angina, reversable d...   (healthy)
# 501    (normal, exercise induced angina, reversable d...   (healthy)
# 507    (male, normal, exercise induced angina, revers...   (healthy)
# 511    (male, normal, exercise induced angina, revers...   (healthy)
# ...                                                  ...         ...
# 20494  (reversable defect, exercise induced angina, m...   (healthy)
# 20503  (reversable defect, exercise induced angina, m...   (healthy)
# 20518  (moderate, reversable defect, exercise induced...   (healthy)
# 20529                (reversable defect, moderate, flat)   (healthy)
# 20534  (typical angina, reversable defect, moderate, ...   (healthy)
#
#        antecedent support  consequent support   support  confidence      lift  \
# ...

# %%
frequent_itemsets = fpgrowth(fdf, min_support=0.1, use_colnames=True)
arules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)

sick=arules[(arules['consequents'] == {'heart disease found'})&
            (arules['confidence'] >= 0.1) &
            (arules['lift'] >= 1) ]

sick
# Out:
#                                               antecedents  \
# 97005                                    (typical angina)
# 97006                  (fasting blood sugar <= 120 mg/dl)
# 97008                                  (no major vessels)
# 97010                                              (high)
# 97013                        (no exercise induced angina)
# ...                                                   ...
# 101348  (fasting blood sugar <= 120 mg/dl, high, no ma...
# 101421                           (no major vessels, male)
# 101447  (no major vessels, fasting blood sugar <= 120 ...
# 101462           (no major vessels, male, typical angina)
# 101475  (fasting blood sugar <= 120 mg/dl, no major ve...
#
#                   consequents  antecedent support  consequent support  \
# 97005   (heart disease found)            1.000000            0.245968
# 97006   (heart disease found)            0.866935            0.245968
# ...

# %%
#ATYPICALANGINA

da= pd.read_csv('heart.csv')
atypical_angina= d[d.cp=='atypical angina']
atrecords = []
for i in range(0, 166):
    atrecords.append([str(atypical_angina.values[i,j]) for j in range(0, 14)])
te = TransactionEncoder()
te_ary = te.fit(atrecords).transform(atrecords)
fdf = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = fpgrowth(fdf, min_support=0.1, use_colnames=True)
atrules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)
atrules["antecedent_len"] =atrules["antecedents"].apply(lambda x: len(x))
atrules[ (atrules['antecedent_len'] >= 3) &
       (atrules['confidence'] > 0.9) &
       (atrules['lift'] > 1) ]
# Out:
#                                                antecedents  \
# 39       (fasting blood sugar <= 120 mg/dl, atypical an...
# 101      (high, no exercise induced angina, no ST segme...
# 115      (atypical angina, high, no exercise induced an...
# 126      (high, no exercise induced angina, no ST segme...
# 170      (fasting blood sugar <= 120 mg/dl, atypical an...
# ...                                                    ...
# 1417661  (atypical angina, reversable defect, heart dis...
# 1417671     (male, reversable defect, heart disease found)
# 1417680     (reversable defect, heart disease found, high)
# 1417683  (reversable defect, heart disease found, no ex...
# 1417684  (reversable defect, heart disease found, no ST...
#
#                                                consequents  \
# 39                            (no exercise induced angina)
# 101                     (fasting blood sugar <= 120 mg/dl)
# 115                     (fasting blood sugar <= 120 mg/dl)
# ...

# %%
atypical_angina['target'].value_counts()
# Out:
# heart disease found    134
# healthy                 33
# Name: target, dtype: int64

# %%
healthy=atrules[(atrules['consequents'] == {'healthy'})&
             (atrules['antecedent_len'] >= 3) &
            (atrules['confidence'] > 0.5) &
            (atrules['lift'] > 1)]
healthy
# Out:
#                                                antecedents consequents  \
# 1344965                              (high, normal, 51-60)   (healthy)
# 1344979                   (atypical angina, normal, 51-60)   (healthy)
# 1344994        (normal, no exercise induced angina, 51-60)   (healthy)
# 1345009             (atypical angina, high, normal, 51-60)   (healthy)
# 1345040  (high, normal, no exercise induced angina, 51-60)   (healthy)
# 1345069  (atypical angina, normal, no exercise induced ...   (healthy)
# 1345100  (atypical angina, 51-60, high, normal, no exer...   (healthy)
#
#          antecedent support  consequent support   support  confidence  \
# 1344965            0.210843            0.198795  0.108434    0.514286
# 1344979            0.210843            0.198795  0.108434    0.514286
# 1344994            0.192771            0.198795  0.108434    0.562500
# 1345009            0.210843            0.198795  0.108434    0.514286
# ...

# %%
sick=atrules[(atrules['consequents'] == {'heart disease found'})&
            (atrules['confidence'] >= 0.4) &
            (atrules['lift'] >= 1) ]

sick
# Out:
#                                                antecedents  \
# 142                                      (atypical angina)
# 145                           (no exercise induced angina)
# 146                     (fasting blood sugar <= 120 mg/dl)
# 149                             (no ST segment depression)
# 153          (atypical angina, no exercise induced angina)
# ...                                                    ...
# 1401523  (no major vessels, fixed defect, no exercise i...
# 1401642  (atypical angina, flat, fasting blood sugar <=...
# 1401705  (flat, fasting blood sugar <= 120 mg/dl, no ma...
# 1401767  (atypical angina, flat, no major vessels, fixe...
# 1401891  (atypical angina, flat, fasting blood sugar <=...
#
#                    consequents  antecedent support  consequent support  \
# 142      (heart disease found)            1.000000            0.801205
# 145      (heart disease found)            0.933735            0.801205
# ...

# %%
#NONANGINALPAIN

da= pd.read_csv('heart.csv')
non_anginal= d[d.cp=='non-anginal pain']
nrecords = []
for i in range(0, 283):
    nrecords.append([str(non_anginal.values[i,j]) for j in range(0, 14)])
te = TransactionEncoder()
te_ary = te.fit(nrecords).transform(nrecords)
fdf = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = fpgrowth(fdf, min_support=0.1, use_colnames=True)
nrules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)
nrules["antecedent_len"] =nrules["antecedents"].apply(lambda x: len(x))
nrules[ (nrules['antecedent_len'] >= 3) &
       (nrules['confidence'] > 0.9) &
       (nrules['lift'] > 1) ]
# Out:
#                                               antecedents  \
# 207     (non-anginal pain, fixed defect, heart disease...
# 208     (non-anginal pain, fixed defect, no exercise i...
# 239     (fasting blood sugar <= 120 mg/dl, non-anginal...
# 268     (fasting blood sugar <= 120 mg/dl, heart disea...
# 281     (fasting blood sugar <= 120 mg/dl, non-anginal...
# ...                                                   ...
# 142579  (reversable defect, non-anginal pain, no ST se...
# 142582  (reversable defect, non-anginal pain, no ST se...
# 142587       (reversable defect, non-anginal pain, 51-60)
# 142593  (reversable defect, non-anginal pain, heart di...
# 142600  (no major vessels, reversable defect, non-angi...
#
#                          consequents  antecedent support  consequent support  \
# 207     (no exercise induced angina)            0.636042            0.869258
# 208            (heart disease found)            0.643110            0.770318
# ...

# %%
non_anginal['target'].value_counts()
# Out:
# heart disease found    219
# healthy                 65
# Name: target, dtype: int64

# %%
healthy=nrules[(nrules['consequents'] == {'healthy'})&
             (nrules['antecedent_len'] >= 3) &
            (nrules['confidence'] > 0.6) &
            (nrules['lift'] > 1)]
healthy
# Out:
#                                              antecedents consequents  \
# 90086                     (male, non-anginal pain, flat)   (healthy)
# 90095                                 (male, high, flat)   (healthy)
# 90107               (male, high, non-anginal pain, flat)   (healthy)
# 90130     (male, fasting blood sugar <= 120 mg/dl, flat)   (healthy)
# 90149  (fasting blood sugar <= 120 mg/dl, non-anginal...   (healthy)
# 90183  (fasting blood sugar <= 120 mg/dl, high, male,...   (healthy)
# 90199  (flat, fasting blood sugar <= 120 mg/dl, high,...   (healthy)
# 90240           (male, no exercise induced angina, flat)   (healthy)
# 90268  (male, non-anginal pain, no exercise induced a...   (healthy)
# 90540                             (male, moderate, flat)   (healthy)
# 90549           (male, non-anginal pain, moderate, flat)   (healthy)
# 90618        (reversable defect, non-anginal pain, flat)   (healthy)
# 90627  (fasting blood sugar <= 120 mg/dl, reversable ...   (healthy)
# ...

# %%
sick=nrules[(nrules['consequents'] == {'heart disease found'})&
            (nrules['confidence'] >= 0.6) &
            (nrules['lift'] >= 1) ]

sick
# Out:
#                                               antecedents  \
# 50                                     (non-anginal pain)
# 53                           (no exercise induced angina)
# 59         (non-anginal pain, no exercise induced angina)
# 71                     (high, no exercise induced angina)
# 77      (high, non-anginal pain, no exercise induced a...
# ...                                                   ...
# 141567  (male, too high, fixed defect, downsloping, no...
# 141633  (male, too high, downsloping, no exercise indu...
# 141697  (male, too high, downsloping, non-anginal pain...
# 141776  (downsloping, no exercise induced angina, too ...
# 141792  (too high, downsloping, non-anginal pain, no e...
#
#                   consequents  antecedent support  consequent support  \
# 50      (heart disease found)            1.000000            0.770318
# 53      (heart disease found)            0.869258            0.770318
# ...

# %%
#ASYMPTOMATIC

da= pd.read_csv('heart.csv')
asymptomatic= d[d.cp=='asymptomatic']
asrecords = []
for i in range(0, 76):
    asrecords.append([str(non_anginal.values[i,j]) for j in range(0, 14)])
te = TransactionEncoder()
te_ary = te.fit(asrecords).transform(asrecords)
fdf = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = fpgrowth(fdf, min_support=0.1, use_colnames=True)
asrules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.3)
asrules["antecedent_len"] =asrules["antecedents"].apply(lambda x: len(x))
asrules[ (asrules['antecedent_len'] >= 1) &
       (asrules['confidence'] > 0.5)&
            (asrules['lift'] >= 1) 
        ]
# Out:
#                                             antecedents  \
# 0                                    (non-anginal pain)
# 1                          (no exercise induced angina)
# 2                    (fasting blood sugar <= 120 mg/dl)
# 3                                    (non-anginal pain)
# 4                    (fasting blood sugar <= 120 mg/dl)
# ...                                                 ...
# 513214  (having ST-T wave abnormality, borderline high)
# 513215      (no ST segment depression, borderline high)
# 513217           (heart disease found, borderline high)
# 513218                   (downsloping, borderline high)
# 513221                                          (29-40)
#
#                                               consequents  antecedent support  \
# 0                            (no exercise induced angina)            1.000000
# 1                                      (non-anginal pain)            0.934211
# ...

# %%
asymptomatic['target'].value_counts()
# Out:
# heart disease found    51
# healthy                26
# Name: target, dtype: int64

# %%
healthy=asrules[(asrules['consequents'] == {'healthy'})&
             (asrules['antecedent_len'] >= 1) &
            (asrules['confidence'] > 0.5) &
            (asrules['lift'] > 1)]
healthy
# Out:
#                                               antecedents consequents  \
# 189719                                       (male, flat)   (healthy)
# 189734                     (male, non-anginal pain, flat)   (healthy)
# 189746           (male, no exercise induced angina, flat)   (healthy)
# 189770  (male, non-anginal pain, no exercise induced a...   (healthy)
# 189790     (male, fasting blood sugar <= 120 mg/dl, flat)   (healthy)
# ...                                                   ...         ...
# 482373                          (male, reversable defect)   (healthy)
# 482384  (male, reversable defect, fasting blood sugar ...   (healthy)
# 482394  (fasting blood sugar <= 120 mg/dl, reversable ...   (healthy)
# 482405        (male, reversable defect, non-anginal pain)   (healthy)
# 482420  (fasting blood sugar <= 120 mg/dl, reversable ...   (healthy)
#
#         antecedent support  consequent support   support  confidence  \
# ...

# %%
sick=asrules[(asrules['consequents'] == {'heart disease found'})&
            (asrules['confidence'] >= 0.5) &
            (asrules['lift'] >= 1) ]

sick
# Out:
#                                               antecedents  \
# 50                                     (non-anginal pain)
# 53                           (no exercise induced angina)
# 54                                                 (high)
# 59         (non-anginal pain, no exercise induced angina)
# 64                               (high, non-anginal pain)
# ...                                                   ...
# 510659  (29-40, fasting blood sugar <= 120 mg/dl, havi...
# 511094  (29-40, fasting blood sugar <= 120 mg/dl, havi...
# 511534  (29-40, fasting blood sugar <= 120 mg/dl, fixe...
# 511920  (29-40, fasting blood sugar <= 120 mg/dl, havi...
# 512348  (29-40, fasting blood sugar <= 120 mg/dl, havi...
#
#                   consequents  antecedent support  consequent support  \
# 50      (heart disease found)            1.000000            0.763158
# 53      (heart disease found)            0.934211            0.763158
# ...

# %%
#MAXIMUM_HEART_RATE_ACHEIVED
#HIGH
da=pd.read_csv('heart.csv')
high=d[d.thalach=='high']

hrecords = []
for i in range(0, 346):
    hrecords.append([str(high.values[i,j]) for j in range(0, 14)])
te = TransactionEncoder()
te_ary = te.fit(hrecords).transform(hrecords)
fdf = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = fpgrowth(fdf, min_support=0.1, use_colnames=True)
hrules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
hrules["antecedent_len"] =hrules["antecedents"].apply(lambda x: len(x))
hrules[ (hrules['antecedent_len'] >= 3) &
       (hrules['confidence'] > 0.99) &
       (hrules['lift'] > 1) ]
# Out:
#                                              antecedents  \
# 3039   (male, having ST-T wave abnormality, fixed def...
# 3061   (male, high, having ST-T wave abnormality, fix...
# 3066   (male, having ST-T wave abnormality, fixed def...
# 3081   (male, having ST-T wave abnormality, fixed def...
# 3092   (male, high, having ST-T wave abnormality, fix...
# ...                                                  ...
# 50867  (fasting blood sugar <= 120 mg/dl, high bp sta...
# 50885  (fasting blood sugar <= 120 mg/dl, high, high ...
# 50892  (fasting blood sugar <= 120 mg/dl, high bp sta...
# 50979                     (high, high bp stage1, female)
# 51011                       (male, high, high bp stage1)
#
#                                     consequents  antecedent support  \
# 3039         (fasting blood sugar <= 120 mg/dl)            0.147399
# 3061         (fasting blood sugar <= 120 mg/dl)            0.147399
# 3066   (fasting blood sugar <= 120 mg/dl, high)            0.147399
# ...

# %%
high['target'].value_counts()
# Out:
# heart disease found    224
# healthy                123
# Name: target, dtype: int64

# %%
healthy=hrules[(hrules['consequents'] == {'healthy'})&
             (hrules['antecedent_len'] >= 1) &
            (hrules['confidence'] > 0.9) &
            (hrules['lift'] > 1)]
healthy
# Out:
#                                              antecedents consequents  \
# 10231                     (male, normal, typical angina)   (healthy)
# 10241               (male, normal, high, typical angina)   (healthy)
# 10848        (normal, reversable defect, typical angina)   (healthy)
# 10851  (normal, reversable defect, high, typical angina)   (healthy)
# 19726                                (two major vessels)   (healthy)
# 19728                          (high, two major vessels)   (healthy)
# 19735                (two major vessels, typical angina)   (healthy)
# 19738          (high, two major vessels, typical angina)   (healthy)
#
#        antecedent support  consequent support   support  confidence      lift  \
# 10231            0.130058            0.355491  0.121387    0.933333  2.625474
# 10241            0.130058            0.355491  0.121387    0.933333  2.625474
# 10848            0.112717            0.355491  0.104046    0.923077  2.596623
# ...

# %%
sick=hrules[(hrules['consequents'] == {'heart disease found'})&
            (hrules['confidence'] >= 0.9) &
            (hrules['lift'] >= 1) ]

sick
# Out:
#                                              antecedents  \
# 328    (male, no major vessels, downsloping, no exerc...
# 339    (male, high, no major vessels, downsloping, no...
# 1123   (male, no major vessels, downsloping, fixed de...
# 1142   (male, high, no major vessels, fixed defect, d...
# 1152   (male, no major vessels, fixed defect, downslo...
# ...                                                  ...
# 50561  (fasting blood sugar <= 120 mg/dl, high, high ...
# 50924  (no major vessels, high bp stage1, no ST segme...
# 50971  (no major vessels, high, high bp stage1, no ST...
# 50983                            (high bp stage1, 51-60)
# 50987                      (high, high bp stage1, 51-60)
#
#                  consequents  antecedent support  consequent support  \
# 328    (heart disease found)            0.208092            0.644509
# 339    (heart disease found)            0.208092            0.644509
# 1123   (heart disease found)            0.150289            0.644509
# ...

# %%
#TOOHIGH
da=pd.read_csv('heart.csv')
too_high=d[d.thalach=='too high']

threcords = []
for i in range(0, 154):
    threcords.append([str(too_high.values[i,j]) for j in range(0, 14)])
te = TransactionEncoder()
te_ary = te.fit(threcords).transform(threcords)
fdf = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = fpgrowth(fdf, min_support=0.1, use_colnames=True)
thrules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
thrules["antecedent_len"] =thrules["antecedents"].apply(lambda x: len(x))
thrules[ (thrules['antecedent_len'] >= 3) &
       (thrules['confidence'] > 0.9) &
       (thrules['lift'] > 1) ]
# Out:
#                                               antecedents  \
# 38      (fasting blood sugar <= 120 mg/dl, heart disea...
# 93                  (male, heart disease found, too high)
# 132     (heart disease found, too high, no ST segment ...
# 161     (fasting blood sugar <= 120 mg/dl, too high, n...
# 185     (fasting blood sugar <= 120 mg/dl, heart disea...
# ...                                                   ...
# 314731  (too high, having ST-T wave abnormality, heart...
# 314733  (no major vessels, too high, heart disease fou...
# 314736  (having ST-T wave abnormality, heart disease f...
# 314738  (too high, heart disease found, J-point only d...
# 314739  (no major vessels, heart disease found, J-poin...
#
#                                              consequents  antecedent support  \
# 38                          (no exercise induced angina)            0.701299
# 93                          (no exercise induced angina)            0.668831
# ...

# %%
too_high['target'].value_counts()
# Out:
# heart disease found    126
# healthy                 29
# Name: target, dtype: int64

# %%
healthy=thrules[(thrules['consequents'] == {'healthy'})&
             (thrules['antecedent_len'] >= 3) &
            (thrules['confidence'] > 0.7) &
            (thrules['lift'] >= 1)]
healthy
# Out:
#                                               antecedents consequents  \
# 314410  (male, reversable defect, fasting blood sugar ...   (healthy)
# 314418  (fasting blood sugar <= 120 mg/dl, reversable ...   (healthy)
# 314426  (fasting blood sugar <= 120 mg/dl, reversable ...   (healthy)
# 314452  (fasting blood sugar <= 120 mg/dl, reversable ...   (healthy)
# 314470  (fasting blood sugar <= 120 mg/dl, reversable ...   (healthy)
# 314487  (fasting blood sugar <= 120 mg/dl, reversable ...   (healthy)
# 314518  (fasting blood sugar <= 120 mg/dl, reversable ...   (healthy)
#
#         antecedent support  consequent support   support  confidence  lift  \
# 314410            0.162338            0.181818  0.123377    0.760000  4.18
# 314418            0.142857            0.181818  0.123377    0.863636  4.75
# 314426            0.162338            0.181818  0.123377    0.760000  4.18
# 314452            0.142857            0.181818  0.123377    0.863636  4.75
# ...

# %%
sick=thrules[(thrules['consequents'] == {'heart disease found'})&
            (thrules['confidence'] >= 0.9) &
            (thrules['lift'] >= 1) ]

sick
# Out:
#                                               antecedents  \
# 375                                        (fixed defect)
# 390                              (fixed defect, too high)
# 395            (fixed defect, no exercise induced angina)
# 401     (no exercise induced angina, fixed defect, too...
# 419      (fasting blood sugar <= 120 mg/dl, fixed defect)
# ...                                                   ...
# 313579  (fasting blood sugar <= 120 mg/dl, high bp sta...
# 313605  (male, too high, fixed defect, downsloping, hi...
# 313621  (fasting blood sugar <= 120 mg/dl, male, too h...
# 313640  (fasting blood sugar <= 120 mg/dl, male, fixed...
# 313661  (fasting blood sugar <= 120 mg/dl, male, too h...
#
#                   consequents  antecedent support  consequent support  \
# 375     (heart disease found)            0.753247            0.818182
# 390     (heart disease found)            0.753247            0.818182
# ...

# %%
#VERYLIGHT
da=pd.read_csv('heart.csv')
very_low=d[d.thalach=='very light']

vlrecords = []
for i in range(0, 94):
    vlrecords.append([str(very_low.values[i,j]) for j in range(0, 14)])
te = TransactionEncoder()
te_ary = te.fit(vlrecords).transform(vlrecords)
fdf = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = fpgrowth(fdf, min_support=0.1, use_colnames=True)
vlrules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)
vlrules["antecedent_len"] =vlrules["antecedents"].apply(lambda x: len(x))
vlrules[ (vlrules['antecedent_len'] >= 3) &
       (vlrules['confidence'] > 0.9) &
       (vlrules['lift'] > 1) ]
# Out:
#                                               antecedents  \
# 28                            (male, very light, healthy)
# 29                     (male, very light, typical angina)
# 31                  (very light, healthy, typical angina)
# 61      (fasting blood sugar <= 120 mg/dl, very light,...
# 75      (fasting blood sugar <= 120 mg/dl, very light,...
# ...                                                   ...
# 997701  (fasting blood sugar <= 120 mg/dl, exercise in...
# 997703  (fasting blood sugar <= 120 mg/dl, normal, bor...
# 997707   (male, exercise induced angina, borderline high)
# 997712  (normal, exercise induced angina, borderline h...
# 997713  (exercise induced angina, borderline high, typ...
#
#                                               consequents  antecedent support  \
# 28                                       (typical angina)            0.755319
# 29                                              (healthy)            0.744681
# ...

# %%
very_low['target'].value_counts()
# Out:
# healthy                83
# heart disease found    12
# Name: target, dtype: int64

# %%
healthy=vlrules[(vlrules['consequents'] == {'healthy'})&
             (vlrules['antecedent_len'] >= 3) &
            (vlrules['confidence'] > 0.7) &
            (vlrules['lift'] >= 1)]
healthy
# Out:
#                                               antecedents consequents  \
# 29                     (male, very light, typical angina)   (healthy)
# 75      (fasting blood sugar <= 120 mg/dl, very light,...   (healthy)
# 90      (fasting blood sugar <= 120 mg/dl, male, typic...   (healthy)
# 105     (fasting blood sugar <= 120 mg/dl, very light,...   (healthy)
# 193                    (high, very light, typical angina)   (healthy)
# ...                                                   ...         ...
# 995986  (very light, flat, fasting blood sugar <= 120 ...   (healthy)
# 996240  (very light, flat, fasting blood sugar <= 120 ...   (healthy)
# 996748  (very light, flat, fasting blood sugar <= 120 ...   (healthy)
# 997002  (very light, flat, male, normal, exercise indu...   (healthy)
# 997257  (very light, flat, fasting blood sugar <= 120 ...   (healthy)
#
#         antecedent support  consequent support   support  confidence  \
# ...

# %%
frequent_itemsets = fpgrowth(fdf, min_support=0.1, use_colnames=True)
vlrules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)

sick=vlrules[(vlrules['consequents'] == {'heart disease found'})&
            (vlrules['confidence'] >= 0.1) &
            (vlrules['lift'] >= 1) ]

sick
# Out:
#          antecedents            consequents  antecedent support  \
# 918958  (very light)  (heart disease found)                 1.0
#
#         consequent support  support  confidence  lift  leverage  conviction
# 918958             0.12766  0.12766     0.12766   1.0       0.0         1.0

# %%
#LIGHT
da=pd.read_csv('heart.csv')
light=d[d.thalach=='light']

lrecords = []
for i in range(0, 171):
    lrecords.append([str(light.values[i,j]) for j in range(0, 14)])
te = TransactionEncoder()
te_ary = te.fit(lrecords).transform(lrecords)
fdf = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = fpgrowth(fdf, min_support=0.1, use_colnames=True)
lrules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)
lrules["antecedent_len"] =lrules["antecedents"].apply(lambda x: len(x))
lrules[ (lrules['antecedent_len'] >= 3) &
       (lrules['confidence'] > 0.9) &
       (lrules['lift'] > 1) ]
# Out:
#                                               antecedents  \
# 29      (fasting blood sugar <= 120 mg/dl, light, typi...
# 31                          (light, typical angina, flat)
# 89      (fasting blood sugar <= 120 mg/dl, normal, typ...
# 91                         (normal, typical angina, flat)
# 105                 (normal, light, typical angina, flat)
# ...                                                   ...
# 333164   (41-50, exercise induced angina, typical angina)
# 333256     (non-anginal pain, heart disease found, light)
# 333284        (no major vessels, non-anginal pain, light)
# 333320   (normal, fasting blood sugar > 120 mg/dl, light)
# 333323     (high, fasting blood sugar > 120 mg/dl, light)
#
#                                               consequents  antecedent support  \
# 29                                                 (flat)            0.643275
# 31                     (fasting blood sugar <= 120 mg/dl)            0.619883
# ...

# %%
light['target'].value_counts()
# Out:
# healthy                120
# heart disease found     52
# Name: target, dtype: int64

# %%
healthy=lrules[(lrules['consequents'] == {'healthy'})&
             (lrules['antecedent_len'] >= 3) &
            (lrules['confidence'] > 0.7) &
            (lrules['lift'] >= 1)]
healthy
# Out:
#                                               antecedents consequents  \
# 584       (male, fasting blood sugar <= 120 mg/dl, light)   (healthy)
# 618     (fasting blood sugar <= 120 mg/dl, light, typi...   (healthy)
# 631                         (male, light, typical angina)   (healthy)
# 645     (male, fasting blood sugar <= 120 mg/dl, typic...   (healthy)
# 662     (fasting blood sugar <= 120 mg/dl, light, male...   (healthy)
# ...                                                   ...         ...
# 332324  (flat, fasting blood sugar <= 120 mg/dl, male,...   (healthy)
# 332450  (flat, fasting blood sugar <= 120 mg/dl, exerc...   (healthy)
# 332576  (fasting blood sugar <= 120 mg/dl, male, exerc...   (healthy)
# 332828  (flat, fasting blood sugar <= 120 mg/dl, male,...   (healthy)
# 332955  (flat, fasting blood sugar <= 120 mg/dl, male,...   (healthy)
#
#         antecedent support  consequent support   support  confidence  \
# ...

# %%
frequent_itemsets = fpgrowth(fdf, min_support=0.1, use_colnames=True)
lrules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)

sick=lrules[(lrules['consequents'] == {'heart disease found'})&
            (lrules['confidence'] >= 0.1) &
            (lrules['lift'] >= 1) ]

sick
# Out:
#                                               antecedents  \
# 252366                                            (light)
# 252371                       (no exercise induced angina)
# 252372                                     (fixed defect)
# 252374                                           (normal)
# 252376                                 (no major vessels)
# ...                                                   ...
# 325236                               (downsloping, light)
# 333208                                 (non-anginal pain)
# 333245     (non-anginal pain, no exercise induced angina)
# 333250                          (non-anginal pain, light)
# 333259  (non-anginal pain, light, no exercise induced ...
#
#                   consequents  antecedent support  consequent support  \
# 252366  (heart disease found)            1.000000            0.304094
# 252371  (heart disease found)            0.391813            0.304094
# ...

# %%
#MODERATE
da=pd.read_csv('heart.csv')
moderate=d[d.thalach=='moderate']

modrecords = []
for i in range(0, 255):
    modrecords.append([str(moderate.values[i,j]) for j in range(0, 14)])
te = TransactionEncoder()
te_ary = te.fit(modrecords).transform(modrecords)
fdf = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = fpgrowth(fdf, min_support=0.3, use_colnames=True)
modrules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
modrules["antecedent_len"] =modrules["antecedents"].apply(lambda x: len(x))
modrules[ (modrules['antecedent_len'] >= 3) &
       (modrules['confidence'] > 0.9) &
       (modrules['lift'] > 1) ]
# Out:
#                                            antecedents       consequents  \
# 191                            (male, normal, healthy)            (high)
# 196                  (male, normal, healthy, moderate)            (high)
# 202                            (male, normal, healthy)  (high, moderate)
# 336                           (normal, moderate, flat)            (high)
# 350                             (male, moderate, flat)            (high)
# 380       (normal, moderate, no ST segment depression)            (high)
# 446  (fasting blood sugar <= 120 mg/dl, reversable ...            (male)
# 451  (fasting blood sugar <= 120 mg/dl, reversable ...            (male)
# 458  (fasting blood sugar <= 120 mg/dl, reversable ...  (male, moderate)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 191            0.341176            0.843137  0.309804    0.908046  1.076985
# 196            0.341176            0.843137  0.309804    0.908046  1.076985
# ...

# %%
moderate['target'].value_counts()
# Out:
# healthy                144
# heart disease found    112
# Name: target, dtype: int64

# %%
healthy=modrules[(modrules['consequents'] == {'healthy'})&
             (modrules['antecedent_len'] >= 3) &
            (modrules['confidence'] > 0.7) &
            (modrules['lift'] >= 1)]
healthy
# Out:
#                                            antecedents consequents  \
# 281                 (normal, moderate, typical angina)   (healthy)
# 287                   (high, moderate, typical angina)   (healthy)
# 476                (reversable defect, moderate, high)   (healthy)
# 480  (fasting blood sugar <= 120 mg/dl, reversable ...   (healthy)
# 487                (male, reversable defect, moderate)   (healthy)
# 508              (normal, moderate, reversable defect)   (healthy)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 281            0.431373            0.560784  0.309804    0.718182  1.280674
# 287            0.415686            0.560784  0.305882    0.735849  1.312178
# 476            0.396078            0.560784  0.317647    0.801980  1.430105
# 480            0.396078            0.560784  0.317647    0.801980  1.430105
# 487            0.407843            0.560784  0.317647    0.778846  1.388852
# ...

# %%
frequent_itemsets = fpgrowth(fdf, min_support=0.3, use_colnames=True)
lrules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

sick=lrules[(lrules['consequents'] == {'heart disease found'})&
            (lrules['confidence'] >= 0.6) &
            (lrules['lift'] >= 1) ]

sick
# Out:
#                                             antecedents  \
# 1050                       (no exercise induced angina)
# 1052                                 (no major vessels)
# 1072             (no exercise induced angina, moderate)
# 1076  (fasting blood sugar <= 120 mg/dl, no exercise...
# 1081                 (high, no exercise induced angina)
# 1087  (fasting blood sugar <= 120 mg/dl, no exercise...
# 1098       (high, no exercise induced angina, moderate)
# 1111                       (no major vessels, moderate)
# 1118                                     (fixed defect)
# 1137                           (fixed defect, moderate)
#
#                 consequents  antecedent support  consequent support   support  \
# 1050  (heart disease found)            0.600000            0.439216  0.364706
# 1052  (heart disease found)            0.509804            0.439216  0.313725
# 1072  (heart disease found)            0.600000            0.439216  0.364706
# ...
